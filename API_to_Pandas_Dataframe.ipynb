# %% [markdown]
# <a href="https://colab.research.google.com/github/Mychoyce/Gomycode-Checkpoints/blob/main/API_to_Pandas_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this checkpoint, we are going to practice consuming public APIs through the NASA public APIs portal.
#
# Portal description : The objective of this portal is to make NASA data, including imagery, eminently accessible to application developers and data professionals. Before starting to use its APIs endpoints, it's mandatory that you generate your API KEY and store it somewhere for later use. The API key acts as the user identifier when requesting the API. To get your KEY, fill in the provided form with your personal information, and then we shall receive an email containing your personal API KEY.
#
# ➡️ NASA API PORTAL
#
# https://i.imgur.com/hisTmpk.png
#
#
#
#
# Instructions
#
# Go to the NASA API portal and generate your API KEY
# Import the requests package and store your API KEY in variable
# Go back to portal website and click on 'browse APIs'
# Click on the first dropdown menu, named 'APOD' and read its documentation
# Follow the provided documentation to ask the API endpoint for the astronomy picture of the day. Get then display the image on your notebook.
# Go through the list of the provided API endpoints once again and select 'Astronomy Picture of the Day' option. Store the results in a pandas dataframe
# Do the necessary data pre-processing tasks on the previous result in order to get a clean dataframe with the following columns :
# Asteroid ID
# Asteroid name
# The Minimal estimated diameter in Kilometre
# Absolute_magnitude
# Relative_velocity(km/s)
# Try to export the new dataframe into a CSV file and share it with your colleagues

# %%
import requests
import pandas as pd

# %%
#API_KEY
API_KEY ='XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'

# %%
# Construct the API request URL
apod_url = "https://api.nasa.gov/planetary/apod"

# %% [markdown]
# # PARAMETERS

# %%
params={'date':'2024-03-28',
        'hd':'true',
        'api_key':API_KEY}

# %%
response = requests.get(apod_url, params=params)
json_data =json.loads(response.text)
image_url = json_data['hdurl']
image_url
# Out:
# 'https://apod.nasa.gov/apod/image/2403/NGC5139_mdf.png'

# %%
# Display the image
apod_url = json_data['hdurl']
print("Astronomy Picture of the Day:")
print(apod_url)
# Out:
# Astronomy Picture of the Day:
# https://apod.nasa.gov/apod/image/2403/NGC5139_mdf.png

# %%
# !wget $apod_url
# Out:
# --2024-04-04 14:34:06--  https://apod.nasa.gov/apod/image/2403/NGC5139_mdf.png
# Resolving apod.nasa.gov (apod.nasa.gov)... 129.164.179.22, 2001:4d0:2310:150::22
# Connecting to apod.nasa.gov (apod.nasa.gov)|129.164.179.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6456125 (6.2M) [image/png]
# Saving to: ‘NGC5139_mdf.png’
#
# NGC5139_mdf.png     100%[===================>]   6.16M  23.5MB/s    in 0.3s
#
# 2024-04-04 14:34:07 (23.5 MB/s) - ‘NGC5139_mdf.png’ saved [6456125/6456125]

# %% [markdown]
# # Retrieve the Astronomy Picture of the Day data and store it in a DataFrame:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('NGC5139_mdf.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
neow_url = "https://api.nasa.gov/neo/rest/v1/feed"

# %%
params2= {
    'api_key':API_KEY,
        'start_date': '2024-04-04'
}

# %%
response2 = requests.get(neow_url, params= params2)

# %%
json_data2 = json.loads(response2.text)
json_data2
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-04-11&end_date=2024-04-18&detailed=false&api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-03-28&end_date=2024-04-04&detailed=false&api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-04-04&end_date=2024-04-11&detailed=false&api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#  'element_count': 126,
#  'near_earth_objects': {'2024-04-06': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3092205?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3092205',
#     'neo_reference_id': '3092205',
#     'name': '(1998 WL4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3092205',
#     'absolute_magnitude_h': 19.49,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3361669212,
#       'estimated_diameter_max': 0.7516920875},
#      'meters': {'estimated_diameter_min': 336.1669211578,
#       'estimated_diameter_max': 751.6920874957},
#      'miles': {'estimated_diameter_min': 0.208884376,
#       'estimated_diameter_max': 0.4670796641},
#      'feet': {'estimated_diameter_min': 1102.9098816115,
#       'estimated_diameter_max': 2466.1814683395}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 23:27',
#       'epoch_date_close_approach': 1712446020000,
#       'relative_velocity': {'kilometers_per_second': '23.8413146294',
#        'kilometers_per_hour': '85828.7326659361',
#        'miles_per_hour': '53330.6366945646'},
#       'miss_distance': {'astronomical': '0.3715043685',
#        'lunar': '144.5151993465',
#        'kilometers': '55576262.223295095',
#        'miles': '34533488.006438511'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3339667?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3339667',
#     'neo_reference_id': '3339667',
#     'name': '(2006 QV89)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3339667',
#     'absolute_magnitude_h': 25.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0211132445,
#       'estimated_diameter_max': 0.0472106499},
#      'meters': {'estimated_diameter_min': 21.113244479,
#       'estimated_diameter_max': 47.2106498806},
#      'miles': {'estimated_diameter_min': 0.0131191578,
#       'estimated_diameter_max': 0.0293353287},
#      'feet': {'estimated_diameter_min': 69.2691770164,
#       'estimated_diameter_max': 154.8905885541}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 04:18',
#       'epoch_date_close_approach': 1712377080000,
#       'relative_velocity': {'kilometers_per_second': '7.5513565618',
#        'kilometers_per_hour': '27184.8836226148',
#        'miles_per_hour': '16891.6294931742'},
#       'miss_distance': {'astronomical': '0.429155972',
#        'lunar': '166.941673108',
#        'kilometers': '64200819.30897964',
#        'miles': '39892539.276973432'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3511515?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3511515',
#     'neo_reference_id': '3511515',
#     'name': '(2010 EG21)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3511515',
#     'absolute_magnitude_h': 24.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0334622374,
#       'estimated_diameter_max': 0.0748238376},
#      'meters': {'estimated_diameter_min': 33.4622374455,
#       'estimated_diameter_max': 74.8238376074},
#      'miles': {'estimated_diameter_min': 0.0207924639,
#       'estimated_diameter_max': 0.0464933628},
#      'feet': {'estimated_diameter_min': 109.7842471007,
#       'estimated_diameter_max': 245.4850393757}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 15:30',
#       'epoch_date_close_approach': 1712417400000,
#       'relative_velocity': {'kilometers_per_second': '8.698438864',
#        'kilometers_per_hour': '31314.379910434',
#        'miles_per_hour': '19457.5378949027'},
#       'miss_distance': {'astronomical': '0.1381277647',
#        'lunar': '53.7317004683',
#        'kilometers': '20663619.386981189',
#        'miles': '12839777.6986668482'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3547799?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3547799',
#     'neo_reference_id': '3547799',
#     'name': '(2010 TK)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3547799',
#     'absolute_magnitude_h': 25.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0231502122,
#       'estimated_diameter_max': 0.0517654482},
#      'meters': {'estimated_diameter_min': 23.150212221,
#       'estimated_diameter_max': 51.7654482198},
#      'miles': {'estimated_diameter_min': 0.0143848705,
#       'estimated_diameter_max': 0.0321655483},
#      'feet': {'estimated_diameter_min': 75.9521422633,
#       'estimated_diameter_max': 169.8341531374}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 20:40',
#       'epoch_date_close_approach': 1712436000000,
#       'relative_velocity': {'kilometers_per_second': '24.2684843342',
#        'kilometers_per_hour': '87366.5436031139',
#        'miles_per_hour': '54286.1726071682'},
#       'miss_distance': {'astronomical': '0.4784907699',
#        'lunar': '186.1329094911',
#        'kilometers': '71581199.991700113',
#        'miles': '44478495.1796150394'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3666925?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3666925',
#     'neo_reference_id': '3666925',
#     'name': '(2014 GJ1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3666925',
#     'absolute_magnitude_h': 24.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#       'estimated_diameter_max': 0.0859092601},
#      'meters': {'estimated_diameter_min': 38.4197891064,
#       'estimated_diameter_max': 85.9092601232},
#      'miles': {'estimated_diameter_min': 0.0238729428,
#       'estimated_diameter_max': 0.0533815229},
#      'feet': {'estimated_diameter_min': 126.0491808919,
#       'estimated_diameter_max': 281.8545369825}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 20:19',
#       'epoch_date_close_approach': 1712434740000,
#       'relative_velocity': {'kilometers_per_second': '20.5107273162',
#        'kilometers_per_hour': '73838.618338374',
#        'miles_per_hour': '45880.4459336413'},
#       'miss_distance': {'astronomical': '0.4224329781',
#        'lunar': '164.3264284809',
#        'kilometers': '63195073.741516647',
#        'miles': '39267597.9602658486'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3736776?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3736776',
#     'neo_reference_id': '3736776',
#     'name': '(2015 XW377)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3736776',
#     'absolute_magnitude_h': 21.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1160259082,
#       'estimated_diameter_max': 0.2594418179},
#      'meters': {'estimated_diameter_min': 116.0259082094,
#       'estimated_diameter_max': 259.4418179074},
#      'miles': {'estimated_diameter_min': 0.0720951346,
#       'estimated_diameter_max': 0.1612096218},
#      'feet': {'estimated_diameter_min': 380.6624406898,
#       'estimated_diameter_max': 851.1870938635}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 14:19',
#       'epoch_date_close_approach': 1712413140000,
#       'relative_velocity': {'kilometers_per_second': '19.0771825801',
#        'kilometers_per_hour': '68677.8572884489',
#        'miles_per_hour': '42673.7497134809'},
#       'miss_distance': {'astronomical': '0.4619903672',
#        'lunar': '179.7142528408',
#        'kilometers': '69112774.893637864',
#        'miles': '42944686.9473119632'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3759750?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3759750',
#     'neo_reference_id': '3759750',
#     'name': '(2016 SK2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3759750',
#     'absolute_magnitude_h': 25.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0231502122,
#       'estimated_diameter_max': 0.0517654482},
#      'meters': {'estimated_diameter_min': 23.150212221,
#       'estimated_diameter_max': 51.7654482198},
#      'miles': {'estimated_diameter_min': 0.0143848705,
#       'estimated_diameter_max': 0.0321655483},
#      'feet': {'estimated_diameter_min': 75.9521422633,
#       'estimated_diameter_max': 169.8341531374}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 15:07',
#       'epoch_date_close_approach': 1712416020000,
#       'relative_velocity': {'kilometers_per_second': '9.1276247627',
#        'kilometers_per_hour': '32859.4491457737',
#        'miles_per_hour': '20417.583831717'},
#       'miss_distance': {'astronomical': '0.355603713',
#        'lunar': '138.329844357',
#        'kilometers': '53197558.02889131',
#        'miles': '33055429.758507678'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3789672?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3789672',
#     'neo_reference_id': '3789672',
#     'name': '(2017 WY14)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3789672',
#     'absolute_magnitude_h': 22.24,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0947447113,
#       'estimated_diameter_max': 0.2118556149},
#      'meters': {'estimated_diameter_min': 94.7447112647,
#       'estimated_diameter_max': 211.8556148964},
#      'miles': {'estimated_diameter_min': 0.058871616,
#       'estimated_diameter_max': 0.1316409353},
#      'feet': {'estimated_diameter_min': 310.8422385057,
#       'estimated_diameter_max': 695.0643755769}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 15:19',
#       'epoch_date_close_approach': 1712416740000,
#       'relative_velocity': {'kilometers_per_second': '16.1849054417',
#        'kilometers_per_hour': '58265.6595901513',
#        'miles_per_hour': '36204.0149825582'},
#       'miss_distance': {'astronomical': '0.3254779214',
#        'lunar': '126.6109114246',
#        'kilometers': '48690803.773467418',
#        'miles': '30255062.5189416484'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3797901?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3797901',
#     'neo_reference_id': '3797901',
#     'name': '(2018 BG5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3797901',
#     'absolute_magnitude_h': 24.08,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0406027058,
#       'estimated_diameter_max': 0.0907904103},
#      'meters': {'estimated_diameter_min': 40.602705828,
#       'estimated_diameter_max': 90.7904103018},
#      'miles': {'estimated_diameter_min': 0.0252293439,
#       'estimated_diameter_max': 0.056414528},
#      'feet': {'estimated_diameter_min': 133.2109813886,
#       'estimated_diameter_max': 297.8688097344}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 14:26',
#       'epoch_date_close_approach': 1712413560000,
#       'relative_velocity': {'kilometers_per_second': '8.4624927889',
#        'kilometers_per_hour': '30464.9740399655',
#        'miles_per_hour': '18929.7501194441'},
#       'miss_distance': {'astronomical': '0.4141370549',
#        'lunar': '161.0993143561',
#        'kilometers': '61954021.301113063',
#        'miles': '38496443.7326957494'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3843611?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3843611',
#     'neo_reference_id': '3843611',
#     'name': '(2019 QU1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843611',
#     'absolute_magnitude_h': 23.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.046190746,
#       'estimated_diameter_max': 0.1032856481},
#      'meters': {'estimated_diameter_min': 46.1907460282,
#       'estimated_diameter_max': 103.2856480504},
#      'miles': {'estimated_diameter_min': 0.0287015901,
#       'estimated_diameter_max': 0.0641787064},
#      'feet': {'estimated_diameter_min': 151.544447199,
#       'estimated_diameter_max': 338.8636855496}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 13:16',
#       'epoch_date_close_approach': 1712409360000,
#       'relative_velocity': {'kilometers_per_second': '15.8504727312',
#        'kilometers_per_hour': '57061.7018322743',
#        'miles_per_hour': '35455.9224523929'},
#       'miss_distance': {'astronomical': '0.3435501756',
#        'lunar': '133.6410183084',
#        'kilometers': '51394374.507885972',
#        'miles': '31934983.4743395336'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54087420?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54087420',
#     'neo_reference_id': '54087420',
#     'name': '(2020 VL)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54087420',
#     'absolute_magnitude_h': 25.12,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0251509837,
#       'estimated_diameter_max': 0.0562393094},
#      'meters': {'estimated_diameter_min': 25.1509837491,
#       'estimated_diameter_max': 56.239309364},
#      'miles': {'estimated_diameter_min': 0.0156280919,
#       'estimated_diameter_max': 0.0349454759},
#      'feet': {'estimated_diameter_min': 82.5163535234,
#       'estimated_diameter_max': 184.5121757337}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 00:51',
#       'epoch_date_close_approach': 1712364660000,
#       'relative_velocity': {'kilometers_per_second': '3.8442379175',
#        'kilometers_per_hour': '13839.2565030045',
#        'miles_per_hour': '8599.1757976586'},
#       'miss_distance': {'astronomical': '0.0744255334',
#        'lunar': '28.9515324926',
#        'kilometers': '11133901.270253858',
#        'miles': '6918285.4441769204'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54144291?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54144291',
#     'neo_reference_id': '54144291',
#     'name': '(2021 JM3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54144291',
#     'absolute_magnitude_h': 27.07,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0102460147,
#       'estimated_diameter_max': 0.0229107855},
#      'meters': {'estimated_diameter_min': 10.2460147468,
#       'estimated_diameter_max': 22.9107854722},
#      'miles': {'estimated_diameter_min': 0.0063665764,
#       'estimated_diameter_max': 0.0142360977},
#      'feet': {'estimated_diameter_min': 33.6155350217,
#       'estimated_diameter_max': 75.1666214087}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 04:33',
#       'epoch_date_close_approach': 1712377980000,
#       'relative_velocity': {'kilometers_per_second': '20.7304166004',
#        'kilometers_per_hour': '74629.4997614602',
#        'miles_per_hour': '46371.8688934473'},
#       'miss_distance': {'astronomical': '0.4331342257',
#        'lunar': '168.4892137973',
#        'kilometers': '64795957.588819259',
#        'miles': '40262341.0561294142'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54431804?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54431804',
#     'neo_reference_id': '54431804',
#     'name': '(2024 FB3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54431804',
#     'absolute_magnitude_h': 22.705,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0764812499,
#       'estimated_diameter_max': 0.1710172737},
#      'meters': {'estimated_diameter_min': 76.4812498637,
#       'estimated_diameter_max': 171.0172736993},
#      'miles': {'estimated_diameter_min': 0.0475232307,
#       'estimated_diameter_max': 0.1062651744},
#      'feet': {'estimated_diameter_min': 250.9227438027,
#       'estimated_diameter_max': 561.0803122437}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-06',
#       'close_approach_date_full': '2024-Apr-06 07:15',
#       'epoch_date_close_approach': 1712387700000,
#       'relative_velocity': {'kilometers_per_second': '3.0518924459',
#        'kilometers_per_hour': '10986.8128053891',
#        'miles_per_hour': '6826.7782123264'},
#       'miss_distance': {'astronomical': '0.3229132157',
#        'lunar': '125.6132409073',
#        'kilometers': '48307129.263570559',
#        'miles': '30016658.2334453542'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-04-07': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2307918?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '2307918',
#     'neo_reference_id': '2307918',
#     'name': '307918 (2004 EU9)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2307918',
#     'absolute_magnitude_h': 19.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4212646106,
#       'estimated_diameter_max': 0.9419763057},
#      'meters': {'estimated_diameter_min': 421.2646105562,
#       'estimated_diameter_max': 941.9763057186},
#      'miles': {'estimated_diameter_min': 0.2617616123,
#       'estimated_diameter_max': 0.5853167591},
#      'feet': {'estimated_diameter_min': 1382.1017848971,
#       'estimated_diameter_max': 3090.4735428537}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 16:40',
#       'epoch_date_close_approach': 1712508000000,
#       'relative_velocity': {'kilometers_per_second': '15.8489956474',
#        'kilometers_per_hour': '57056.3843305212',
#        'miles_per_hour': '35452.6183635952'},
#       'miss_distance': {'astronomical': '0.4412313236',
#        'lunar': '171.6389848804',
#        'kilometers': '66007266.187840732',
#        'miles': '41015013.3176848216'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3443808?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3443808',
#     'neo_reference_id': '3443808',
#     'name': '(2008 YY32)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3443808',
#     'absolute_magnitude_h': 25.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#       'estimated_diameter_max': 0.0542050786},
#      'meters': {'estimated_diameter_min': 24.2412481101,
#       'estimated_diameter_max': 54.2050786336},
#      'miles': {'estimated_diameter_min': 0.0150628086,
#       'estimated_diameter_max': 0.0336814639},
#      'feet': {'estimated_diameter_min': 79.5316564495,
#       'estimated_diameter_max': 177.8381901842}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 04:20',
#       'epoch_date_close_approach': 1712463600000,
#       'relative_velocity': {'kilometers_per_second': '18.7660248453',
#        'kilometers_per_hour': '67557.6894430886',
#        'miles_per_hour': '41977.7209764569'},
#       'miss_distance': {'astronomical': '0.3319635773',
#        'lunar': '129.1338315697',
#        'kilometers': '49661044.081660351',
#        'miles': '30857941.8905648038'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3579748?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3579748',
#     'neo_reference_id': '3579748',
#     'name': '(2011 SY120)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3579748',
#     'absolute_magnitude_h': 23.27,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0589596608,
#       'estimated_diameter_max': 0.1318378096},
#      'meters': {'estimated_diameter_min': 58.9596608383,
#       'estimated_diameter_max': 131.8378095647},
#      'miles': {'estimated_diameter_min': 0.0366358234,
#       'estimated_diameter_max': 0.0819201916},
#      'feet': {'estimated_diameter_min': 193.4372136647,
#       'estimated_diameter_max': 432.5387591324}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 04:15',
#       'epoch_date_close_approach': 1712463300000,
#       'relative_velocity': {'kilometers_per_second': '25.2500296259',
#        'kilometers_per_hour': '90900.1066530762',
#        'miles_per_hour': '56481.7912700739'},
#       'miss_distance': {'astronomical': '0.4744044759',
#        'lunar': '184.5433411251',
#        'kilometers': '70969899.113106333',
#        'miles': '44098650.4272920754'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3666916?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3666916',
#     'neo_reference_id': '3666916',
#     'name': '(2014 GF1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3666916',
#     'absolute_magnitude_h': 26.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#       'estimated_diameter_max': 0.0375007522},
#      'meters': {'estimated_diameter_min': 16.7708462163,
#       'estimated_diameter_max': 37.5007521798},
#      'miles': {'estimated_diameter_min': 0.0104209175,
#       'estimated_diameter_max': 0.0233018799},
#      'feet': {'estimated_diameter_min': 55.0224631002,
#       'estimated_diameter_max': 123.0339677816}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 01:27',
#       'epoch_date_close_approach': 1712453220000,
#       'relative_velocity': {'kilometers_per_second': '7.840274154',
#        'kilometers_per_hour': '28224.986954243',
#        'miles_per_hour': '17537.909254985'},
#       'miss_distance': {'astronomical': '0.0513730909',
#        'lunar': '19.9841323601',
#        'kilometers': '7685304.973956383',
#        'miles': '4775427.0713207654'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3714457?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3714457',
#     'neo_reference_id': '3714457',
#     'name': '(2015 FV117)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3714457',
#     'absolute_magnitude_h': 22.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1010543415,
#       'estimated_diameter_max': 0.2259643771},
#      'meters': {'estimated_diameter_min': 101.054341542,
#       'estimated_diameter_max': 225.9643771094},
#      'miles': {'estimated_diameter_min': 0.0627922373,
#       'estimated_diameter_max': 0.140407711},
#      'feet': {'estimated_diameter_min': 331.5431259047,
#       'estimated_diameter_max': 741.3529669956}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 08:32',
#       'epoch_date_close_approach': 1712478720000,
#       'relative_velocity': {'kilometers_per_second': '26.2721533513',
#        'kilometers_per_hour': '94579.7520647275',
#        'miles_per_hour': '58768.1798315525'},
#       'miss_distance': {'astronomical': '0.3783466398',
#        'lunar': '147.1768428822',
#        'kilometers': '56599851.435737226',
#        'miles': '35169516.8500006788'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771800?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3771800',
#     'neo_reference_id': '3771800',
#     'name': '(2017 FQ63)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3771800',
#     'absolute_magnitude_h': 25.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0253837029,
#       'estimated_diameter_max': 0.0567596853},
#      'meters': {'estimated_diameter_min': 25.3837029364,
#       'estimated_diameter_max': 56.7596852866},
#      'miles': {'estimated_diameter_min': 0.0157726969,
#       'estimated_diameter_max': 0.0352688224},
#      'feet': {'estimated_diameter_min': 83.279867942,
#       'estimated_diameter_max': 186.2194458756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 03:50',
#       'epoch_date_close_approach': 1712461800000,
#       'relative_velocity': {'kilometers_per_second': '19.9671638706',
#        'kilometers_per_hour': '71881.7899342334',
#        'miles_per_hour': '44664.5488621908'},
#       'miss_distance': {'astronomical': '0.4078596548',
#        'lunar': '158.6574057172',
#        'kilometers': '61014935.617015276',
#        'miles': '37912922.9468157688'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3798973?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3798973',
#     'neo_reference_id': '3798973',
#     'name': '(2018 BN6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3798973',
#     'absolute_magnitude_h': 26.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0116025908,
#       'estimated_diameter_max': 0.0259441818},
#      'meters': {'estimated_diameter_min': 11.6025908209,
#       'estimated_diameter_max': 25.9441817907},
#      'miles': {'estimated_diameter_min': 0.0072095135,
#       'estimated_diameter_max': 0.0161209622},
#      'feet': {'estimated_diameter_min': 38.066244069,
#       'estimated_diameter_max': 85.1187093863}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 11:20',
#       'epoch_date_close_approach': 1712488800000,
#       'relative_velocity': {'kilometers_per_second': '9.7401737798',
#        'kilometers_per_hour': '35064.6256072107',
#        'miles_per_hour': '21787.7947279916'},
#       'miss_distance': {'astronomical': '0.477625616',
#        'lunar': '185.796364624',
#        'kilometers': '71451774.81103792',
#        'miles': '44398074.101526496'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3943344?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3943344',
#     'neo_reference_id': '3943344',
#     'name': '(2019 YT1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3943344',
#     'absolute_magnitude_h': 25.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#       'estimated_diameter_max': 0.0542050786},
#      'meters': {'estimated_diameter_min': 24.2412481101,
#       'estimated_diameter_max': 54.2050786336},
#      'miles': {'estimated_diameter_min': 0.0150628086,
#       'estimated_diameter_max': 0.0336814639},
#      'feet': {'estimated_diameter_min': 79.5316564495,
#       'estimated_diameter_max': 177.8381901842}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 04:29',
#       'epoch_date_close_approach': 1712464140000,
#       'relative_velocity': {'kilometers_per_second': '3.1043100602',
#        'kilometers_per_hour': '11175.5162168882',
#        'miles_per_hour': '6944.0311737659'},
#       'miss_distance': {'astronomical': '0.2433013045',
#        'lunar': '94.6442074505',
#        'kilometers': '36397356.921421415',
#        'miles': '22616268.860648927'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54204652?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54204652',
#     'neo_reference_id': '54204652',
#     'name': '(2021 TT4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54204652',
#     'absolute_magnitude_h': 28.13,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0062886146,
#       'estimated_diameter_max': 0.0140617696},
#      'meters': {'estimated_diameter_min': 6.2886145559,
#       'estimated_diameter_max': 14.0617696313},
#      'miles': {'estimated_diameter_min': 0.0039075627,
#       'estimated_diameter_max': 0.0087375759},
#      'feet': {'estimated_diameter_min': 20.6319381796,
#       'estimated_diameter_max': 46.1344162772}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 23:55',
#       'epoch_date_close_approach': 1712534100000,
#       'relative_velocity': {'kilometers_per_second': '17.1953607719',
#        'kilometers_per_hour': '61903.2987788605',
#        'miles_per_hour': '38464.3025106759'},
#       'miss_distance': {'astronomical': '0.4954729906',
#        'lunar': '192.7389933434',
#        'kilometers': '74121704.036290022',
#        'miles': '46057091.1924534236'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54386833?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54386833',
#     'neo_reference_id': '54386833',
#     'name': '(2023 RX36)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54386833',
#     'absolute_magnitude_h': 24.39,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.035200998,
#       'estimated_diameter_max': 0.0787118244},
#      'meters': {'estimated_diameter_min': 35.2009980055,
#       'estimated_diameter_max': 78.7118244161},
#      'miles': {'estimated_diameter_min': 0.0218728793,
#       'estimated_diameter_max': 0.048909245},
#      'feet': {'estimated_diameter_min': 115.4888422963,
#       'estimated_diameter_max': 258.2409020172}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 06:14',
#       'epoch_date_close_approach': 1712470440000,
#       'relative_velocity': {'kilometers_per_second': '10.9806884776',
#        'kilometers_per_hour': '39530.478519288',
#        'miles_per_hour': '24562.7020554987'},
#       'miss_distance': {'astronomical': '0.3278308704',
#        'lunar': '127.5262085856',
#        'kilometers': '49042799.932086048',
#        'miles': '30473782.7897135424'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426895?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54426895',
#     'neo_reference_id': '54426895',
#     'name': '(2024 CY6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426895',
#     'absolute_magnitude_h': 22.48,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0848310762,
#       'estimated_diameter_max': 0.189688053},
#      'meters': {'estimated_diameter_min': 84.8310761886,
#       'estimated_diameter_max': 189.6880529621},
#      'miles': {'estimated_diameter_min': 0.0527115706,
#       'estimated_diameter_max': 0.1178666552},
#      'feet': {'estimated_diameter_min': 278.3171880025,
#       'estimated_diameter_max': 622.3361516803}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 07:53',
#       'epoch_date_close_approach': 1712476380000,
#       'relative_velocity': {'kilometers_per_second': '6.1990632154',
#        'kilometers_per_hour': '22316.627575544',
#        'miles_per_hour': '13866.6845065929'},
#       'miss_distance': {'astronomical': '0.1745294333',
#        'lunar': '67.8919495537',
#        'kilometers': '26109231.473987071',
#        'miles': '16223524.1431247398'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54431310?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54431310',
#     'neo_reference_id': '54431310',
#     'name': '(2024 FG)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54431310',
#     'absolute_magnitude_h': 24.061,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0409595311,
#       'estimated_diameter_max': 0.0915882959},
#      'meters': {'estimated_diameter_min': 40.9595311343,
#       'estimated_diameter_max': 91.5882959428},
#      'miles': {'estimated_diameter_min': 0.0254510648,
#       'estimated_diameter_max': 0.056910311},
#      'feet': {'estimated_diameter_min': 134.3816681267,
#       'estimated_diameter_max': 300.4865448611}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 06:34',
#       'epoch_date_close_approach': 1712471640000,
#       'relative_velocity': {'kilometers_per_second': '9.8020462108',
#        'kilometers_per_hour': '35287.3663589145',
#        'miles_per_hour': '21926.19716896'},
#       'miss_distance': {'astronomical': '0.0316322472',
#        'lunar': '12.3049441608',
#        'kilometers': '4732116.804433464',
#        'miles': '2940401.0340672432'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54431627?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54431627',
#     'neo_reference_id': '54431627',
#     'name': '(2024 FH2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54431627',
#     'absolute_magnitude_h': 22.244,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0945703457,
#       'estimated_diameter_max': 0.2114657216},
#      'meters': {'estimated_diameter_min': 94.5703457028,
#       'estimated_diameter_max': 211.4657216471},
#      'miles': {'estimated_diameter_min': 0.0587632703,
#       'estimated_diameter_max': 0.1313986669},
#      'feet': {'estimated_diameter_min': 310.2701729955,
#       'estimated_diameter_max': 693.7851982086}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 18:32',
#       'epoch_date_close_approach': 1712514720000,
#       'relative_velocity': {'kilometers_per_second': '19.7705394702',
#        'kilometers_per_hour': '71173.9420926656',
#        'miles_per_hour': '44224.7197408566'},
#       'miss_distance': {'astronomical': '0.0412561801',
#        'lunar': '16.0486540589',
#        'kilometers': '6171836.667296387',
#        'miles': '3835001.4736766606'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54432222?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54432222',
#     'neo_reference_id': '54432222',
#     'name': '(2024 GB)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54432222',
#     'absolute_magnitude_h': 23.924,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0436269625,
#       'estimated_diameter_max': 0.0975528538},
#      'meters': {'estimated_diameter_min': 43.6269625049,
#       'estimated_diameter_max': 97.5528538129},
#      'miles': {'estimated_diameter_min': 0.0271085293,
#       'estimated_diameter_max': 0.0606165143},
#      'feet': {'estimated_diameter_min': 143.1330836647,
#       'estimated_diameter_max': 320.0553049035}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-07',
#       'close_approach_date_full': '2024-Apr-07 23:24',
#       'epoch_date_close_approach': 1712532240000,
#       'relative_velocity': {'kilometers_per_second': '8.9630464952',
#        'kilometers_per_hour': '32266.9673827712',
#        'miles_per_hour': '20049.4387051447'},
#       'miss_distance': {'astronomical': '0.0351767691',
#        'lunar': '13.6837631799',
#        'kilometers': '5262369.730841817',
#        'miles': '3269884.9241663946'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-04-04': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2010165?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '2010165',
#     'neo_reference_id': '2010165',
#     'name': '10165 (1995 BL2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2010165',
#     'absolute_magnitude_h': 17.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.8801465209,
#       'estimated_diameter_max': 1.9680674509},
#      'meters': {'estimated_diameter_min': 880.1465209007,
#       'estimated_diameter_max': 1968.067450894},
#      'miles': {'estimated_diameter_min': 0.5468975238,
#       'estimated_diameter_max': 1.22290004},
#      'feet': {'estimated_diameter_min': 2887.6199116319,
#       'estimated_diameter_max': 6456.914415591}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-04',
#       'close_approach_date_full': '2024-Apr-04 23:44',
#       'epoch_date_close_approach': 1712274240000,
#       'relative_velocity': {'kilometers_per_second': '14.6416274317',
#        'kilometers_per_hour': '52709.8587540617',
#        'miles_per_hour': '32751.8564019335'},
#       'miss_distance': {'astronomical': '0.3930134681',
#        'lunar': '152.8822390909',
#        'kilometers': '58793977.709072947',
#        'miles': '36532883.6960907886'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2025330?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '2025330',
#     'neo_reference_id': '2025330',
#     'name': '25330 (1999 KV4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2025330',
#     'absolute_magnitude_h': 16.75,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.1872849879,
#       'estimated_diameter_max': 2.6548499417},
#      'meters': {'estimated_diameter_min': 1187.2849879373,
#       'estimated_diameter_max': 2654.8499416927},
#      'miles': {'estimated_diameter_min': 0.7377444602,
#       'estimated_diameter_max': 1.6496467631},
#      'feet': {'estimated_diameter_min': 3895.2920798241,
#       'estimated_diameter_max': 8710.1378827032}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-04',
#       'close_approach_date_full': '2024-Apr-04 01:57',
#       'epoch_date_close_approach': 1712195820000,
#       'relative_velocity': {'kilometers_per_second': '8.8126324018',
#        'kilometers_per_hour': '31725.4766466077',
#        'miles_per_hour': '19712.9774196658'},
#       'miss_distance': {'astronomical': '0.1961801746',
#        'lunar': '76.3140879194',
#        'kilometers': '29348136.256388102',
#        'miles': '18236086.2511637276'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3277463?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3277463',
#     'neo_reference_id': '3277463',
#     'name': '(2005 HB4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3277463',
#     'absolute_magnitude_h': 24.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0350392641,
#       'estimated_diameter_max': 0.0783501764},
#      'meters': {'estimated_diameter_min': 35.0392641108,
#       'estimated_diameter_max': 78.3501764334},
#      'miles': {'estimated_diameter_min': 0.0217723826,
#       'estimated_diameter_max': 0.0486845275},
#      'feet': {'estimated_diameter_min': 114.9582192654,
#       'estimated_diameter_max': 257.0543928497}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-04',
#       'close_approach_date_full': '2024-Apr-04 13:46',
#       'epoch_date_close_approach': 1712238360000,
#       'relative_velocity': {'kilometers_per_second': '15.7428171061',
#        'kilometers_per_hour': '56674.1415818556',
#        'miles_per_hour': '35215.1075845702'},
#       'miss_distance': {'astronomical': '0.4497183895',
#        'lunar': '174.9404535155',
#        'kilometers': '67276913.169030365',
#        'miles': '41803935.368994437'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3740662?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3740662',
#     'neo_reference_id': '3740662',
#     'name': '(2016 AX147)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3740662',
#     'absolute_magnitude_h': 17.65,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7844314124,
#       'estimated_diameter_max': 1.7540419619},
#      'meters': {'estimated_diameter_min': 784.4314124479,
#       'estimated_diameter_max': 1754.0419619197},
#      'miles': {'estimated_diameter_min': 0.4874229312,
#       'estimated_diameter_max': 1.0899108079},
#      'feet': {'estimated_diameter_min': 2573.5939552157,
#       'estimated_diameter_max': 5754.7310303447}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-04',
#       'close_approach_date_full': '2024-Apr-04 04:28',
#       'epoch_date_close_approach': 1712204880000,
#       'relative_velocity': {'kilometers_per_second': '12.6067509608',
#        'kilometers_per_hour': '45384.3034589588',
#        'miles_per_hour': '28200.0412242625'},
#       'miss_distance': {'astronomical': '0.304802351',
#        'lunar': '118.568114539',
#        'kilometers': '45597782.48059237',
#        'miles': '28333148.207899906'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3752457?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3752457',
#     'neo_reference_id': '3752457',
#     'name': '(2016 HP6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3752457',
#     'absolute_magnitude_h': 25.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#       'estimated_diameter_max': 0.0494356193},
#      'meters': {'estimated_diameter_min': 22.1082810359,
#       'estimated_diameter_max': 49.435619262},
#      'miles': {'estimated_diameter_min': 0.0137374447,
#       'estimated_diameter_max': 0.0307178602},
#      'feet': {'estimated_diameter_min': 72.5337327539,
#       'estimated_diameter_max': 162.1903570994}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-04',
#       'close_approach_date_full': '2024-Apr-04 19:16',
#       'epoch_date_close_approach': 1712258160000,
#       'relative_velocity': {'kilometers_per_second': '12.1559850785',
#        'kilometers_per_hour': '43761.546282605',
#        'miles_per_hour': '27191.7230220998'},
#       'miss_distance': {'astronomical': '0.2234831156',
#        'lunar': '86.9349319684',
#        'kilometers': '33432598.074723772',
#        'miles': '20774053.1379891736'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3766160?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3766160',
#     'neo_reference_id': '3766160',
#     'name': '(2016 YW7)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3766160',
#     'absolute_magnitude_h': 20.68,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1943367684,
#       'estimated_diameter_max': 0.4345502246},
#      'meters': {'estimated_diameter_min': 194.3367683899,
#       'estimated_diameter_max': 434.5502246474},
#      'miles': {'estimated_diameter_min': 0.1207552321,
#       'estimated_diameter_max': 0.2700169076},
#      'feet': {'estimated_diameter_min': 637.5878432043,
#       'estimated_diameter_max': 1425.6897590323}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-04-04',
#       'close_approach_date_full': '2024-Apr-04 13:01',
#       'epoch_date_close_approach': 1712235660000,
#       'relative_velocity': {'kilometers_per_second': '20.9037406236',
#        'kilometers_per_hour': '75253.466244861',
#        'miles_per_hour': '46759.5774008693'},
#       'miss_distance': {'astronomical': '0.1965196225',
#        'lunar': '76.4461331525',
#        'kilometers': '29398916.939204075',
#        'miles': '18267639.904303235'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3836919?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3836919',
#     'neo_reference_id': '3836919',
#     'name': '(2018 XF5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836919',
#     'absolute_magnitude_h': 23.62,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0501828101,
#       'estimated_diameter_max': 0.1122121746},
#      'meters': {'estimated_diameter_min': 50.182810059,
#       'estimated_diameter_max': 112.2121745938},
#      'miles': {'estimated_diameter_min': 0.0311821429,
#       'estimated_diameter_max': 0.0697253911},
#      'feet': {'estimated_diameter_min': 164.6417705539,
#       'estimated_diameter_max': 368.1501908944}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-04',
#       'close_approach_date_full': '2024-Apr-04 06:56',
#       'epoch_date_close_approach': 1712213760000,
#       'relative_velocity': {'kilometers_per_second': '3.5175582343',
#        'kilometers_per_hour': '12663.2096436077',
#        'miles_per_hour': '7868.426014385'},
#       'miss_distance': {'astronomical': '0.214370028',
#        'lunar': '83.389940892',
#        'kilometers': '32069299.58064036',
#        'miles': '19926938.734982568'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3843824?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3843824',
#     'neo_reference_id': '3843824',
#     'name': '(2019 RH2)',
# ...
#       'estimated_diameter_max': 705.3830669336}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-10',
#       'close_approach_date_full': '2024-Apr-10 00:49',
#       'epoch_date_close_approach': 1712710140000,
#       'relative_velocity': {'kilometers_per_second': '20.4276188077',
#        'kilometers_per_hour': '73539.4277077934',
#        'miles_per_hour': '45694.5405109898'},
#       'miss_distance': {'astronomical': '0.139573216',
#        'lunar': '54.293981024',
#        'kilometers': '20879855.82264992',
#        'miles': '12974140.789292096'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54431772?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54431772',
#     'neo_reference_id': '54431772',
#     'name': '(2024 FT2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54431772',
#     'absolute_magnitude_h': 25.308,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0230650806,
#       'estimated_diameter_max': 0.0515750881},
#      'meters': {'estimated_diameter_min': 23.0650806019,
#       'estimated_diameter_max': 51.5750881323},
#      'miles': {'estimated_diameter_min': 0.0143319722,
#       'estimated_diameter_max': 0.0320472641},
#      'feet': {'estimated_diameter_min': 75.6728390418,
#       'estimated_diameter_max': 169.2096121479}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-10',
#       'close_approach_date_full': '2024-Apr-10 14:09',
#       'epoch_date_close_approach': 1712758140000,
#       'relative_velocity': {'kilometers_per_second': '11.9267083088',
#        'kilometers_per_hour': '42936.1499115155',
#        'miles_per_hour': '26678.8538158525'},
#       'miss_distance': {'astronomical': '0.0303339772',
#        'lunar': '11.7999171308',
#        'kilometers': '4537898.377748564',
#        'miles': '2819719.2998116232'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54432218?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54432218',
#     'neo_reference_id': '54432218',
#     'name': '(2024 FZ3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54432218',
#     'absolute_magnitude_h': 25.685,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0193889806,
#       'estimated_diameter_max': 0.0433550787},
#      'meters': {'estimated_diameter_min': 19.3889806226,
#       'estimated_diameter_max': 43.3550786865},
#      'miles': {'estimated_diameter_min': 0.0120477503,
#       'estimated_diameter_max': 0.0269395886},
#      'feet': {'estimated_diameter_min': 63.6121431857,
#       'estimated_diameter_max': 142.2410763578}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-10',
#       'close_approach_date_full': '2024-Apr-10 13:18',
#       'epoch_date_close_approach': 1712755080000,
#       'relative_velocity': {'kilometers_per_second': '8.2173670601',
#        'kilometers_per_hour': '29582.5214162949',
#        'miles_per_hour': '18381.4283766972'},
#       'miss_distance': {'astronomical': '0.0632981944',
#        'lunar': '24.6229976216',
#        'kilometers': '9469275.057085928',
#        'miles': '5883934.6787966864'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-04-11': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2215588?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '2215588',
#     'neo_reference_id': '2215588',
#     'name': '215588 (2003 HF2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2215588',
#     'absolute_magnitude_h': 19.42,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3471802221,
#       'estimated_diameter_max': 0.776318577},
#      'meters': {'estimated_diameter_min': 347.1802220654,
#       'estimated_diameter_max': 776.3185769818},
#      'miles': {'estimated_diameter_min': 0.2157277218,
#       'estimated_diameter_max': 0.4823818505},
#      'feet': {'estimated_diameter_min': 1139.0427597612,
#       'estimated_diameter_max': 2546.977040105}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 02:49',
#       'epoch_date_close_approach': 1712803740000,
#       'relative_velocity': {'kilometers_per_second': '32.6920334547',
#        'kilometers_per_hour': '117691.3204369459',
#        'miles_per_hour': '73128.8096348345'},
#       'miss_distance': {'astronomical': '0.3568109978',
#        'lunar': '138.7994781442',
#        'kilometers': '53378165.263454686',
#        'miles': '33167653.8901632268'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2363599?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '2363599',
#     'neo_reference_id': '2363599',
#     'name': '363599 (2004 FG11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2363599',
#     'absolute_magnitude_h': 21.04,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1646474378,
#       'estimated_diameter_max': 0.3681628631},
#      'meters': {'estimated_diameter_min': 164.6474377554,
#       'estimated_diameter_max': 368.1628631423},
#      'miles': {'estimated_diameter_min': 0.102307143,
#       'estimated_diameter_max': 0.2287657264},
#      'feet': {'estimated_diameter_min': 540.1818996855,
#       'estimated_diameter_max': 1207.8834479116}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 09:36',
#       'epoch_date_close_approach': 1712828160000,
#       'relative_velocity': {'kilometers_per_second': '24.7446688728',
#        'kilometers_per_hour': '89080.8079419043',
#        'miles_per_hour': '55351.3498014572'},
#       'miss_distance': {'astronomical': '0.0520956603',
#        'lunar': '20.2652118567',
#        'kilometers': '7793399.817123561',
#        'miles': '4842594.0922887018'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3604480?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3604480',
#     'neo_reference_id': '3604480',
#     'name': '(2012 KK11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3604480',
#     'absolute_magnitude_h': 25.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0231502122,
#       'estimated_diameter_max': 0.0517654482},
#      'meters': {'estimated_diameter_min': 23.150212221,
#       'estimated_diameter_max': 51.7654482198},
#      'miles': {'estimated_diameter_min': 0.0143848705,
#       'estimated_diameter_max': 0.0321655483},
#      'feet': {'estimated_diameter_min': 75.9521422633,
#       'estimated_diameter_max': 169.8341531374}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 23:45',
#       'epoch_date_close_approach': 1712879100000,
#       'relative_velocity': {'kilometers_per_second': '15.8268447693',
#        'kilometers_per_hour': '56976.6411693781',
#        'miles_per_hour': '35403.0690643839'},
#       'miss_distance': {'astronomical': '0.4073222704',
#        'lunar': '158.4483631856',
#        'kilometers': '60934544.055404048',
#        'miles': '37862969.9467819424'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3662960?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3662960',
#     'neo_reference_id': '3662960',
#     'name': '(2014 DD112)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3662960',
#     'absolute_magnitude_h': 23.99,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.042320908,
#       'estimated_diameter_max': 0.0946324271},
#      'meters': {'estimated_diameter_min': 42.320907965,
#       'estimated_diameter_max': 94.6324270793},
#      'miles': {'estimated_diameter_min': 0.0262969849,
#       'estimated_diameter_max': 0.0588018458},
#      'feet': {'estimated_diameter_min': 138.848127688,
#       'estimated_diameter_max': 310.4738520588}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 04:20',
#       'epoch_date_close_approach': 1712809200000,
#       'relative_velocity': {'kilometers_per_second': '4.5501400773',
#        'kilometers_per_hour': '16380.504278286',
#        'miles_per_hour': '10178.2083389161'},
#       'miss_distance': {'astronomical': '0.323306412',
#        'lunar': '125.766194268',
#        'kilometers': '48365950.59254244',
#        'miles': '30053208.112428072'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3712627?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '3712627',
#     'neo_reference_id': '3712627',
#     'name': '(2015 DK200)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3712627',
#     'absolute_magnitude_h': 25.59,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0202560601,
#       'estimated_diameter_max': 0.0452939273},
#      'meters': {'estimated_diameter_min': 20.2560600865,
#       'estimated_diameter_max': 45.2939273097},
#      'miles': {'estimated_diameter_min': 0.0125865283,
#       'estimated_diameter_max': 0.0281443329},
#      'feet': {'estimated_diameter_min': 66.4568921741,
#       'estimated_diameter_max': 148.6021284747}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 10:29',
#       'epoch_date_close_approach': 1712831340000,
#       'relative_velocity': {'kilometers_per_second': '6.6620802825',
#        'kilometers_per_hour': '23983.4890169301',
#        'miles_per_hour': '14902.4073838808'},
#       'miss_distance': {'astronomical': '0.1067245581',
#        'lunar': '41.5158531009',
#        'kilometers': '15965766.568451247',
#        'miles': '9920667.3181793286'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016662?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54016662',
#     'neo_reference_id': '54016662',
#     'name': '(2020 HK3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016662',
#     'absolute_magnitude_h': 24.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#       'estimated_diameter_max': 0.0859092601},
#      'meters': {'estimated_diameter_min': 38.4197891064,
#       'estimated_diameter_max': 85.9092601232},
#      'miles': {'estimated_diameter_min': 0.0238729428,
#       'estimated_diameter_max': 0.0533815229},
#      'feet': {'estimated_diameter_min': 126.0491808919,
#       'estimated_diameter_max': 281.8545369825}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 14:59',
#       'epoch_date_close_approach': 1712847540000,
#       'relative_velocity': {'kilometers_per_second': '35.1534571977',
#        'kilometers_per_hour': '126552.4459115648',
#        'miles_per_hour': '78634.7684054387'},
#       'miss_distance': {'astronomical': '0.4076013388',
#        'lunar': '158.5569207932',
#        'kilometers': '60976292.093628356',
#        'miles': '37888910.9748330728'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54138713?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54138713',
#     'neo_reference_id': '54138713',
#     'name': '(2021 HF1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54138713',
#     'absolute_magnitude_h': 27.85,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0071540995,
#       'estimated_diameter_max': 0.0159970528},
#      'meters': {'estimated_diameter_min': 7.1540995088,
#       'estimated_diameter_max': 15.9970528196},
#      'miles': {'estimated_diameter_min': 0.00444535,
#       'estimated_diameter_max': 0.0099401047},
#      'feet': {'estimated_diameter_min': 23.4714558326,
#       'estimated_diameter_max': 52.4837707725}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 19:50',
#       'epoch_date_close_approach': 1712865000000,
#       'relative_velocity': {'kilometers_per_second': '7.6854696031',
#        'kilometers_per_hour': '27667.6905712662',
#        'miles_per_hour': '17191.6269552404'},
#       'miss_distance': {'astronomical': '0.1799612615',
#        'lunar': '70.0049307235',
#        'kilometers': '26921821.402913005',
#        'miles': '16728444.111509269'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54231259?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54231259',
#     'neo_reference_id': '54231259',
#     'name': '(2021 YB)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54231259',
#     'absolute_magnitude_h': 27.52,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0083282735,
#       'estimated_diameter_max': 0.0186225856},
#      'meters': {'estimated_diameter_min': 8.3282734552,
#       'estimated_diameter_max': 18.6225855811},
#      'miles': {'estimated_diameter_min': 0.0051749476,
#       'estimated_diameter_max': 0.0115715346},
#      'feet': {'estimated_diameter_min': 27.3237326829,
#       'estimated_diameter_max': 61.0977236779}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 09:32',
#       'epoch_date_close_approach': 1712827920000,
#       'relative_velocity': {'kilometers_per_second': '4.836061357',
#        'kilometers_per_hour': '17409.8208850377',
#        'miles_per_hour': '10817.7856493724'},
#       'miss_distance': {'astronomical': '0.1637876745',
#        'lunar': '63.7134053805',
#        'kilometers': '24502287.237453315',
#        'miles': '15225015.296013147'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54431494?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#     'id': '54431494',
#     'neo_reference_id': '54431494',
#     'name': '(2024 FA1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54431494',
#     'absolute_magnitude_h': 22.653,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0783348429,
#       'estimated_diameter_max': 0.1751620337},
#      'meters': {'estimated_diameter_min': 78.3348428673,
#       'estimated_diameter_max': 175.162033658},
#      'miles': {'estimated_diameter_min': 0.0486749996,
#       'estimated_diameter_max': 0.108840608},
#      'feet': {'estimated_diameter_min': 257.0040858727,
#       'estimated_diameter_max': 574.6786065065}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-04-11',
#       'close_approach_date_full': '2024-Apr-11 07:43',
#       'epoch_date_close_approach': 1712821380000,
#       'relative_velocity': {'kilometers_per_second': '9.3291984837',
#        'kilometers_per_hour': '33585.1145412365',
#        'miles_per_hour': '20868.4840881367'},
#       'miss_distance': {'astronomical': '0.1900760923',
#        'lunar': '73.9395999047',
#        'kilometers': '28434978.546003401',
#        'miles': '17668676.3610768938'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
all_object_near_earth = json_data2['near_earth_objects']['2024-04-04']
all_object_near_earth
# Out:
# [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2010165?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '2010165',
#   'neo_reference_id': '2010165',
#   'name': '10165 (1995 BL2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2010165',
#   'absolute_magnitude_h': 17.4,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.8801465209,
#     'estimated_diameter_max': 1.9680674509},
#    'meters': {'estimated_diameter_min': 880.1465209007,
#     'estimated_diameter_max': 1968.067450894},
#    'miles': {'estimated_diameter_min': 0.5468975238,
#     'estimated_diameter_max': 1.22290004},
#    'feet': {'estimated_diameter_min': 2887.6199116319,
#     'estimated_diameter_max': 6456.914415591}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 23:44',
#     'epoch_date_close_approach': 1712274240000,
#     'relative_velocity': {'kilometers_per_second': '14.6416274317',
#      'kilometers_per_hour': '52709.8587540617',
#      'miles_per_hour': '32751.8564019335'},
#     'miss_distance': {'astronomical': '0.3930134681',
#      'lunar': '152.8822390909',
#      'kilometers': '58793977.709072947',
#      'miles': '36532883.6960907886'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2025330?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '2025330',
#   'neo_reference_id': '2025330',
#   'name': '25330 (1999 KV4)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2025330',
#   'absolute_magnitude_h': 16.75,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 1.1872849879,
#     'estimated_diameter_max': 2.6548499417},
#    'meters': {'estimated_diameter_min': 1187.2849879373,
#     'estimated_diameter_max': 2654.8499416927},
#    'miles': {'estimated_diameter_min': 0.7377444602,
#     'estimated_diameter_max': 1.6496467631},
#    'feet': {'estimated_diameter_min': 3895.2920798241,
#     'estimated_diameter_max': 8710.1378827032}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 01:57',
#     'epoch_date_close_approach': 1712195820000,
#     'relative_velocity': {'kilometers_per_second': '8.8126324018',
#      'kilometers_per_hour': '31725.4766466077',
#      'miles_per_hour': '19712.9774196658'},
#     'miss_distance': {'astronomical': '0.1961801746',
#      'lunar': '76.3140879194',
#      'kilometers': '29348136.256388102',
#      'miles': '18236086.2511637276'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3277463?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '3277463',
#   'neo_reference_id': '3277463',
#   'name': '(2005 HB4)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3277463',
#   'absolute_magnitude_h': 24.4,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0350392641,
#     'estimated_diameter_max': 0.0783501764},
#    'meters': {'estimated_diameter_min': 35.0392641108,
#     'estimated_diameter_max': 78.3501764334},
#    'miles': {'estimated_diameter_min': 0.0217723826,
#     'estimated_diameter_max': 0.0486845275},
#    'feet': {'estimated_diameter_min': 114.9582192654,
#     'estimated_diameter_max': 257.0543928497}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 13:46',
#     'epoch_date_close_approach': 1712238360000,
#     'relative_velocity': {'kilometers_per_second': '15.7428171061',
#      'kilometers_per_hour': '56674.1415818556',
#      'miles_per_hour': '35215.1075845702'},
#     'miss_distance': {'astronomical': '0.4497183895',
#      'lunar': '174.9404535155',
#      'kilometers': '67276913.169030365',
#      'miles': '41803935.368994437'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3740662?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '3740662',
#   'neo_reference_id': '3740662',
#   'name': '(2016 AX147)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3740662',
#   'absolute_magnitude_h': 17.65,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7844314124,
#     'estimated_diameter_max': 1.7540419619},
#    'meters': {'estimated_diameter_min': 784.4314124479,
#     'estimated_diameter_max': 1754.0419619197},
#    'miles': {'estimated_diameter_min': 0.4874229312,
#     'estimated_diameter_max': 1.0899108079},
#    'feet': {'estimated_diameter_min': 2573.5939552157,
#     'estimated_diameter_max': 5754.7310303447}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 04:28',
#     'epoch_date_close_approach': 1712204880000,
#     'relative_velocity': {'kilometers_per_second': '12.6067509608',
#      'kilometers_per_hour': '45384.3034589588',
#      'miles_per_hour': '28200.0412242625'},
#     'miss_distance': {'astronomical': '0.304802351',
#      'lunar': '118.568114539',
#      'kilometers': '45597782.48059237',
#      'miles': '28333148.207899906'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3752457?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '3752457',
#   'neo_reference_id': '3752457',
#   'name': '(2016 HP6)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3752457',
#   'absolute_magnitude_h': 25.4,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#     'estimated_diameter_max': 0.0494356193},
#    'meters': {'estimated_diameter_min': 22.1082810359,
#     'estimated_diameter_max': 49.435619262},
#    'miles': {'estimated_diameter_min': 0.0137374447,
#     'estimated_diameter_max': 0.0307178602},
#    'feet': {'estimated_diameter_min': 72.5337327539,
#     'estimated_diameter_max': 162.1903570994}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 19:16',
#     'epoch_date_close_approach': 1712258160000,
#     'relative_velocity': {'kilometers_per_second': '12.1559850785',
#      'kilometers_per_hour': '43761.546282605',
#      'miles_per_hour': '27191.7230220998'},
#     'miss_distance': {'astronomical': '0.2234831156',
#      'lunar': '86.9349319684',
#      'kilometers': '33432598.074723772',
#      'miles': '20774053.1379891736'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3766160?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '3766160',
#   'neo_reference_id': '3766160',
#   'name': '(2016 YW7)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3766160',
#   'absolute_magnitude_h': 20.68,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1943367684,
#     'estimated_diameter_max': 0.4345502246},
#    'meters': {'estimated_diameter_min': 194.3367683899,
#     'estimated_diameter_max': 434.5502246474},
#    'miles': {'estimated_diameter_min': 0.1207552321,
#     'estimated_diameter_max': 0.2700169076},
#    'feet': {'estimated_diameter_min': 637.5878432043,
#     'estimated_diameter_max': 1425.6897590323}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 13:01',
#     'epoch_date_close_approach': 1712235660000,
#     'relative_velocity': {'kilometers_per_second': '20.9037406236',
#      'kilometers_per_hour': '75253.466244861',
#      'miles_per_hour': '46759.5774008693'},
#     'miss_distance': {'astronomical': '0.1965196225',
#      'lunar': '76.4461331525',
#      'kilometers': '29398916.939204075',
#      'miles': '18267639.904303235'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3836919?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '3836919',
#   'neo_reference_id': '3836919',
#   'name': '(2018 XF5)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836919',
#   'absolute_magnitude_h': 23.62,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0501828101,
#     'estimated_diameter_max': 0.1122121746},
#    'meters': {'estimated_diameter_min': 50.182810059,
#     'estimated_diameter_max': 112.2121745938},
#    'miles': {'estimated_diameter_min': 0.0311821429,
#     'estimated_diameter_max': 0.0697253911},
#    'feet': {'estimated_diameter_min': 164.6417705539,
#     'estimated_diameter_max': 368.1501908944}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 06:56',
#     'epoch_date_close_approach': 1712213760000,
#     'relative_velocity': {'kilometers_per_second': '3.5175582343',
#      'kilometers_per_hour': '12663.2096436077',
#      'miles_per_hour': '7868.426014385'},
#     'miss_distance': {'astronomical': '0.214370028',
#      'lunar': '83.389940892',
#      'kilometers': '32069299.58064036',
#      'miles': '19926938.734982568'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3843824?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '3843824',
#   'neo_reference_id': '3843824',
#   'name': '(2019 RH2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843824',
#   'absolute_magnitude_h': 25.3,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0231502122,
#     'estimated_diameter_max': 0.0517654482},
#    'meters': {'estimated_diameter_min': 23.150212221,
#     'estimated_diameter_max': 51.7654482198},
#    'miles': {'estimated_diameter_min': 0.0143848705,
#     'estimated_diameter_max': 0.0321655483},
#    'feet': {'estimated_diameter_min': 75.9521422633,
#     'estimated_diameter_max': 169.8341531374}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 22:57',
#     'epoch_date_close_approach': 1712271420000,
#     'relative_velocity': {'kilometers_per_second': '6.0517115629',
#      'kilometers_per_hour': '21786.1616265341',
#      'miles_per_hour': '13537.0735951095'},
#     'miss_distance': {'astronomical': '0.2523564166',
#      'lunar': '98.1666460574',
#      'kilometers': '37751982.404192642',
#      'miles': '23457994.1043247796'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016396?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '54016396',
#   'neo_reference_id': '54016396',
#   'name': '(2020 FW5)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016396',
#   'absolute_magnitude_h': 25.72,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0190789723,
#     'estimated_diameter_max': 0.0426618789},
#    'meters': {'estimated_diameter_min': 19.078972262,
#     'estimated_diameter_max': 42.6618789186},
#    'miles': {'estimated_diameter_min': 0.0118551201,
#     'estimated_diameter_max': 0.0265088544},
#    'feet': {'estimated_diameter_min': 62.595055356,
#     'estimated_diameter_max': 139.9667988315}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 11:15',
#     'epoch_date_close_approach': 1712229300000,
#     'relative_velocity': {'kilometers_per_second': '11.8851168712',
#      'kilometers_per_hour': '42786.4207364698',
#      'miles_per_hour': '26585.8179292803'},
#     'miss_distance': {'astronomical': '0.0781760368',
#      'lunar': '30.4104783152',
#      'kilometers': '11694968.590321616',
#      'miles': '7266916.5106296608'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016579?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '54016579',
#   'neo_reference_id': '54016579',
#   'name': '(2020 HD1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016579',
#   'absolute_magnitude_h': 23.74,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0474848397,
#     'estimated_diameter_max': 0.1061793296},
#    'meters': {'estimated_diameter_min': 47.4848397396,
#     'estimated_diameter_max': 106.1793295584},
#    'miles': {'estimated_diameter_min': 0.0295057024,
#     'estimated_diameter_max': 0.0659767562},
#    'feet': {'estimated_diameter_min': 155.7901616112,
#     'estimated_diameter_max': 348.3573915882}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 11:14',
#     'epoch_date_close_approach': 1712229240000,
#     'relative_velocity': {'kilometers_per_second': '15.3995113403',
#      'kilometers_per_hour': '55438.240824909',
#      'miles_per_hour': '34447.1669170108'},
#     'miss_distance': {'astronomical': '0.328011326',
#      'lunar': '127.596405814',
#      'kilometers': '49069795.70547562',
#      'miles': '30490557.185458756'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54051022?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '54051022',
#   'neo_reference_id': '54051022',
#   'name': '(2020 PH2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54051022',
#   'absolute_magnitude_h': 21.0,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1677084622,
#     'estimated_diameter_max': 0.3750075218},
#    'meters': {'estimated_diameter_min': 167.7084621628,
#     'estimated_diameter_max': 375.0075217981},
#    'miles': {'estimated_diameter_min': 0.1042091748,
#     'estimated_diameter_max': 0.2330187988},
#    'feet': {'estimated_diameter_min': 550.2246310023,
#     'estimated_diameter_max': 1230.3396778159}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 12:14',
#     'epoch_date_close_approach': 1712232840000,
#     'relative_velocity': {'kilometers_per_second': '26.6466954403',
#      'kilometers_per_hour': '95928.103584922',
#      'miles_per_hour': '59605.9930303089'},
#     'miss_distance': {'astronomical': '0.2997974623',
#      'lunar': '116.6212128347',
#      'kilometers': '44849061.791485301',
#      'miles': '27867914.7448511138'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54132112?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '54132112',
#   'neo_reference_id': '54132112',
#   'name': '(2021 FD1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54132112',
#   'absolute_magnitude_h': 26.66,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0123752784,
#     'estimated_diameter_max': 0.0276719637},
#    'meters': {'estimated_diameter_min': 12.3752783658,
#     'estimated_diameter_max': 27.6719636665},
#    'miles': {'estimated_diameter_min': 0.0076896391,
#     'estimated_diameter_max': 0.0171945557},
#    'feet': {'estimated_diameter_min': 40.6013082738,
#     'estimated_diameter_max': 90.7872852756}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 12:45',
#     'epoch_date_close_approach': 1712234700000,
#     'relative_velocity': {'kilometers_per_second': '8.8482311886',
#      'kilometers_per_hour': '31853.6322789334',
#      'miles_per_hour': '19792.6083457628'},
#     'miss_distance': {'astronomical': '0.0059992049',
#      'lunar': '2.3336907061',
#      'kilometers': '897468.274733563',
#      'miles': '557660.9268386494'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54354397?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '54354397',
#   'neo_reference_id': '54354397',
#   'name': '(2023 GC2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54354397',
#   'absolute_magnitude_h': 27.33,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0090898136,
#     'estimated_diameter_max': 0.0203254411},
#    'meters': {'estimated_diameter_min': 9.089813582,
#     'estimated_diameter_max': 20.3254410722},
#    'miles': {'estimated_diameter_min': 0.0056481466,
#     'estimated_diameter_max': 0.0126296396},
#    'feet': {'estimated_diameter_min': 29.8222239924,
#     'estimated_diameter_max': 66.6845200873}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 00:35',
#     'epoch_date_close_approach': 1712190900000,
#     'relative_velocity': {'kilometers_per_second': '5.6845356837',
#      'kilometers_per_hour': '20464.3284614074',
#      'miles_per_hour': '12715.7378709229'},
#     'miss_distance': {'astronomical': '0.0223892542',
#      'lunar': '8.7094198838',
#      'kilometers': '3349384.739208554',
#      'miles': '2081211.1698998852'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54391007?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '54391007',
#   'neo_reference_id': '54391007',
#   'name': '(2023 TC1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54391007',
#   'absolute_magnitude_h': 26.9,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0110803882,
#     'estimated_diameter_max': 0.0247765013},
#    'meters': {'estimated_diameter_min': 11.0803882126,
#     'estimated_diameter_max': 24.7765012606},
#    'miles': {'estimated_diameter_min': 0.0068850319,
#     'estimated_diameter_max': 0.0153953994},
#    'feet': {'estimated_diameter_min': 36.3529808636,
#     'estimated_diameter_max': 81.2877363957}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 23:28',
#     'epoch_date_close_approach': 1712273280000,
#     'relative_velocity': {'kilometers_per_second': '6.8097486874',
#      'kilometers_per_hour': '24515.095274605',
#      'miles_per_hour': '15232.7268388233'},
#     'miss_distance': {'astronomical': '0.3669812344',
#      'lunar': '142.7557001816',
#      'kilometers': '54899610.996210728',
#      'miles': '34113036.4305269264'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54391014?api_key=XQ6eMAHfOAMQnK9RM2GoTcuSM2e9BCaHvYm1EMJG'},
#   'id': '54391014',
#   'neo_reference_id': '54391014',
#   'name': '(2023 TK1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54391014',
#   'absolute_magnitude_h': 23.86,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.04493192,
#     'estimated_diameter_max': 0.1004708274},
#    'meters': {'estimated_diameter_min': 44.9319199631,
#     'estimated_diameter_max': 100.470827397},
#    'miles': {'estimated_diameter_min': 0.027919392,
#     'estimated_diameter_max': 0.0624296585},
#    'feet': {'estimated_diameter_min': 147.4144402917,
#     'estimated_diameter_max': 329.6287093572}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-04-04',
#     'close_approach_date_full': '2024-Apr-04 15:05',
#     'epoch_date_close_approach': 1712243100000,
#     'relative_velocity': {'kilometers_per_second': '15.0338948131',
#      'kilometers_per_hour': '54122.0213270117',
#      'miles_per_hour': '33629.3193073312'},
#     'miss_distance': {'astronomical': '0.2685805412',
#      'lunar': '104.4778305268',
#      'kilometers': '40179076.886967244',
#      'miles': '24966120.6831622072'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False}]

# %%
all_object_near_earth = json_data2['near_earth_objects']['2024-04-04']
all_object_near_earth

# %%
df = pd.DataFrame([near_earth_objects['id'], near_earth_objects['name'], near_earth_objects['estimated_diameter']['kilometers']['estimated_diameter_min'], near_earth_objects['absolute_magnitude_h'], near_earth_objects['close_approach_data'][0]['relative_velocity']['kilometers_per_second']] for near_earth_objects in all_object_near_earth )
df.columns = columns=('Asteroid ID', 'Asteroid name','Minimal estimated diameter in Kilometre', 'Absolute_magnitude', 'Relative velocity(km/s)')
df
